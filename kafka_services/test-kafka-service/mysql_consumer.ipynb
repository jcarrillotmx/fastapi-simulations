# %%
from kafka import KafkaConsumer
import json
import time

# Configuración del consumidor
consumer = KafkaConsumer(
    'rigcore-data',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='latest',
    enable_auto_commit=True,
    group_id='rigcore-consumer-group',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

print("Esperando mensajes agrupados por tabla cada 3 segundos...")

try:
    while True:
        # Inicializar buffer para este intervalo
        message_buffer = {}

        # Leer todos los mensajes disponibles durante este intervalo
        start_time = time.time()
        while time.time() - start_time < 3:
            raw_msgs = consumer.poll(timeout_ms=500)
            for tp, messages in raw_msgs.items():
                for msg in messages:
                    data = msg.value
                    table = data.get('table')
                    row_data = data.get('data')

                    if table and row_data:
                        message_buffer[table] = {
                            'table': table, 'data': row_data}
                    else:
                        print(f"[WARN] Formato inesperado: {data}")

        # Imprimir todos los mensajes agrupados
        if message_buffer:
            print("\n=== Lote de datos recibido ===")
            for table, full_data in message_buffer.items():
                print(f"[Kafka] Sent from {table}: {full_data}")
            print("==============================\n")

        time.sleep(3)  # Esperar el siguiente ciclo

except KeyboardInterrupt:
    print("\nLectura interrumpida por el usuario.")

finally:
    consumer.close()
    print("Consumer cerrado correctamente.")
# Out:
# Esperando mensajes agrupados por tabla cada 3 segundos...
#
# === Lote de datos recibido ===
# [Kafka] Sent from calculos_config: {'table': 'calculos_config', 'data': {'id': 15, 'id_codigo': 'codigo_01', 'session_timestamp': '2025-06-08T13:00:00', 'nombre': 'suma', 'descripcion': 'Descripción del cálculo1', 'formula': 'var1+var2', 'timestamp_created': '2025-06-15T02:55:35'}}
# [Kafka] Sent from calculos_resultado: {'table': 'calculos_resultado', 'data': {'id': 909, 'timestamp': '2025-06-14T19:27:24', 'session_timestamp': '2025-06-08T13:00:00', 'codigo_01': 'gene', 'resultado_01': '0.0000', 'unidad_01': '', 'codigo_02': None, 'resultado_02': None, 'unidad_02': None, 'codigo_03': None, 'resultado_03': None, 'unidad_03': None, 'codigo_04': None, 'resultado_04': None, 'unidad_04': None, 'codigo_05': None, 'resultado_05': None, 'unidad_05': None, 'codigo_06': None, 'resultado_06': None, 'unidad_06': None, 'codigo_07': None, 'resultado_07': None, 'unidad_07': None, 'codigo_08': None, 'resultado_08': None, 'unidad_08': None, 'codigo_09': None, 'resultado_09': None, 'unidad_09': None, 'codigo_10': None, 'resultado_10': None, 'unidad_10': None, 'codigo_11': None, 'resultado_11': None, 'unidad_11': None, 'codigo_12': None, 'resultado_12': None, 'unidad_12': None, 'codigo_13': None, 'resultado_13': None, 'unidad_13': None, 'codigo_14': None, 'resultado_14': None, 'unidad_14': None, 'codigo_15': None, 'resultado_15': None, 'unidad_15': None, 'codigo_16': None, 'resultado_16': None, 'unidad_16': None, 'codigo_17': None, 'resultado_17': None, 'unidad_17': None, 'codigo_18': None, 'resultado_18': None, 'unidad_18': None, 'codigo_19': None, 'resultado_19': None, 'unidad_19': None, 'codigo_20': None, 'resultado_20': None, 'unidad_20': None}}
# [Kafka] Sent from codigo_calculo: {'table': 'codigo_calculo', 'data': {'id': 21, 'codigo': 'cal21'}}
# [Kafka] Sent from drilling_sessions: {'table': 'drilling_sessions', 'data': {'id': 4, 'session_timestamp': '2025-06-08T13:00:00', 'session_name': 'pozo ixachi 3', 'rig_config_id': 3, 'status': 'active', 'start_depth': 0.0, 'end_depth': 1000.0, 'duration_hours': None, 'notes': 'prueba 3', 'created_at': '2025-06-08T13:18:50', 'updated_at': '2025-06-08T13:33:51', 'config_json': '{"session_info": {"session_name": "pozo ixachi 3", "rig_config_id": 3, "rig_name": "rig odin", "status": {"code": "active", "display": "Activo"}, "etapa": "Perforación"}, "depths": {"start": {"value": 0.0, "unit": "m"}, "end": {"value": 1000.0, "unit": "m"}, "difference": {"value": 1000.0, "unit": "m"}}, "timing": {"timestamp": "2025-06-08 13:00:00", "date": "2025-06-08", "time": "13:00:00", "duration_hours": null}, "notes": "prueba 3", "metadata": {"created_at": "2025-06-08 13:33:51", "version": "1.0", "app": "Sistema Escalable de Monitoreo"}}'}}
# [Kafka] Sent from fgenerador1_data: {'table': 'fgenerador1_data', 'data': {'id': 4136, 'timestamp': '2025-06-20T16:39:49', 'rig_config_id': 3, 'session_timestamp': '2025-06-08T13:00:00', 'name_1': 'Status Word ', 'channel_01': 200.0, 'unit_01': 'unidad', 'name_2': 'Status Word 2', 'channel_02': 167363.0, 'unit_02': 'unidad', 'name_3': 'Engine Fuel Rate. Differencial', 'channel_03': 38.0, 'unit_03': 'l', 'name_4': 'Total Fuel Used Differencial (Clearabe)', 'channel_04': 414.0, 'unit_04': 'l', 'name_5': 'Flowmeter Hours Of Operation (Clearable)', 'channel_05': 21.0, 'unit_05': 'm/s', 'name_6': 'Flowmeter Hours Of Operation Suministro A-Gen (Clearable)', 'channel_06': 631.0, 'unit_06': 'unidad', 'name_7': 'Total Fuel Used  Retorno A-Gen (Clearabe)', 'channel_07': 300.0, 'unit_07': 'unidad', 'name_8': 'Flowmeter Hours Of Operation Retorno A-Gen (Clearable)', 'channel_08': 89.0, 'unit_08': 'unidad', 'name_9': 'Engine temperature Suministro', 'channel_09': 87.0, 'unit_09': 'unidad', 'name_10': 'Engine temperature Retorno', 'channel_10': 82.0, 'unit_10': '°C', 'name_11': 'Voltaje', 'channel_11': 78.0, 'unit_11': 'l', 'name_12': 'Corriente', 'channel_12': 73.0, 'unit_12': 'unidad', 'name_13': 'Frecuencia ', 'channel_13': 73.0, 'unit_13': 'unidad', 'name_14': 'Potencia Aparente ', 'channel_14': 239.0, 'unit_14': 'unidad', 'name_15': 'Potencia Activa', 'channel_15': 75.0, 'unit_15': 'unidad', 'name_16': 'Potencia Reactiva', 'channel_16': 85.0, 'unit_16': 'unidad', 'name_17': 'Factor Potencia ', 'channel_17': 75.0, 'unit_17': 'unidad', 'name_18': 'Canal 18', 'channel_18': 67.0, 'unit_18': 'unidad'}}
# [Kafka] Sent from fgenerador2_data: {'table': 'fgenerador2_data', 'data': {'id': 1440, 'timestamp': '2025-06-01T23:59:00', 'rig_config_id': 1, 'session_timestamp': '2025-06-05T00:00:00', 'channel_01': 104.28, 'name_1': 'Canal 1', 'unit_01': 'bar', 'channel_02': 114.01, 'name_2': 'Canal 2', 'unit_02': 'kg/m³', 'channel_03': 116.0, 'name_3': 'Canal 3', 'unit_03': 'l', 'channel_04': 125.77, 'name_4': 'Canal 4', 'unit_04': '°C', 'channel_05': 138.5, 'name_5': 'Canal 5', 'unit_05': 'gpm', 'channel_06': 150.82, 'name_6': 'Canal 6', 'unit_06': 'kg/m³', 'channel_07': 162.13, 'name_7': 'Canal 7', 'unit_07': '°F', 'channel_08': 165.35, 'name_8': 'Canal 8', 'unit_08': '°F', 'channel_09': 184.9, 'name_9': 'Canal 9', 'unit_09': 'l', 'channel_10': 189.24, 'name_10': 'Canal 10', 'unit_10': 'kg/m³', 'channel_11': 201.95, 'name_11': 'Canal 11', 'unit_11': 'm³/h', 'channel_12': 209.31, 'name_12': 'Canal 12', 'unit_12': 'in', 'channel_13': 223.66, 'name_13': 'Canal 13', 'unit_13': 'ft', 'channel_14': 227.49, 'name_14': 'Canal 14', 'unit_14': 'm³', 'channel_15': 236.36, 'name_15': 'Canal 15', 'unit_15': 'lb', 'channel_16': 247.01, 'name_16': 'Canal 16', 'unit_16': 'bar', 'channel_17': 259.54, 'name_17': 'Canal 17', 'unit_17': 'kg/m³', 'channel_18': 269.08, 'name_18': 'Canal 18', 'unit_18': 'ft'}}
# [Kafka] Sent from fgenerador3_data: {'table': 'fgenerador3_data', 'data': {'id': 1440, 'timestamp': '2025-06-01T23:59:00', 'rig_config_id': 1, 'session_timestamp': '2025-06-05T00:00:00', 'channel_01': 104.16, 'name_1': 'Canal 1', 'unit_01': 'deg/s', 'channel_02': 113.76, 'name_2': 'Canal 2', 'unit_02': 'psi', 'channel_03': 118.62, 'name_3': 'Canal 3', 'unit_03': 'g/cm³', 'channel_04': 133.5, 'name_4': 'Canal 4', 'unit_04': 'kPa', 'channel_05': 140.56, 'name_5': 'Canal 5', 'unit_05': 'K', 'channel_06': 150.12, 'name_6': 'Canal 6', 'unit_06': 'ton', 'channel_07': 161.2, 'name_7': 'Canal 7', 'unit_07': 'rad/s', 'channel_08': 165.25, 'name_8': 'Canal 8', 'unit_08': 'l/min', 'channel_09': 180.98, 'name_9': 'Canal 9', 'unit_09': 'kPa', 'channel_10': 189.1, 'name_10': 'Canal 10', 'unit_10': 'in', 'channel_11': 200.0, 'name_11': 'Canal 11', 'unit_11': 'bar', 'channel_12': 207.76, 'name_12': 'Canal 12', 'unit_12': 'K', 'channel_13': 219.68, 'name_13': 'Canal 13', 'unit_13': 'gpm', 'channel_14': 228.02, 'name_14': 'Canal 14', 'unit_14': 'psi', 'channel_15': 242.08, 'name_15': 'Canal 15', 'unit_15': 'psi', 'channel_16': 245.19, 'name_16': 'Canal 16', 'unit_16': 'ton', 'channel_17': 257.34, 'name_17': 'Canal 17', 'unit_17': 'lb', 'channel_18': 269.51, 'name_18': 'Canal 18', 'unit_18': 'l/min'}}
# [Kafka] Sent from fgenerador4_data: {'table': 'fgenerador4_data', 'data': {'id': 1440, 'timestamp': '2025-06-01T23:59:00', 'rig_config_id': 1, 'session_timestamp': '2025-06-05T00:00:00', 'channel_01': 100.48, 'name_1': 'Canal 1', 'unit_01': 'deg/s', 'channel_02': 112.65, 'name_2': 'Canal 2', 'unit_02': 'ft', 'channel_03': 116.28, 'name_3': 'Canal 3', 'unit_03': 'l', 'channel_04': 127.97, 'name_4': 'Canal 4', 'unit_04': 'ft', 'channel_05': 138.89, 'name_5': 'Canal 5', 'unit_05': 'deg/s', 'channel_06': 148.15, 'name_6': 'Canal 6', 'unit_06': 'lb/ft³', 'channel_07': 161.53, 'name_7': 'Canal 7', 'unit_07': 'scaled', 'channel_08': 168.02, 'name_8': 'Canal 8', 'unit_08': '°C', 'channel_09': 180.28, 'name_9': 'Canal 9', 'unit_09': 'lb', 'channel_10': 194.97, 'name_10': 'Canal 10', 'unit_10': 'rpm', 'channel_11': 196.16, 'name_11': 'Canal 11', 'unit_11': 'rad/s', 'channel_12': 210.76, 'name_12': 'Canal 12', 'unit_12': 'l/min', 'channel_13': 224.33, 'name_13': 'Canal 13', 'unit_13': 'kg', 'channel_14': 225.85, 'name_14': 'Canal 14', 'unit_14': 'm', 'channel_15': 238.58, 'name_15': 'Canal 15', 'unit_15': 'K', 'channel_16': 249.33, 'name_16': 'Canal 16', 'unit_16': 'rpm', 'channel_17': 257.44, 'name_17': 'Canal 17', 'unit_17': 'm', 'channel_18': 265.73, 'name_18': 'Canal 18', 'unit_18': 'l/min'}}
# [Kafka] Sent from fgenerador5_data: {'table': 'fgenerador5_data', 'data': {'id': 1440, 'timestamp': '2025-06-01T23:59:00', 'rig_config_id': 1, 'session_timestamp': '2025-06-05T00:00:00', 'channel_01': 98.78, 'name_1': 'Canal 1', 'unit_01': 'kg/m³', 'channel_02': 111.17, 'name_2': 'Canal 2', 'unit_02': 'deg/s', 'channel_03': 122.77, 'name_3': 'Canal 3', 'unit_03': 'l', 'channel_04': 127.67, 'name_4': 'Canal 4', 'unit_04': 'lb', 'channel_05': 143.26, 'name_5': 'Canal 5', 'unit_05': 'ft', 'channel_06': 151.09, 'name_6': 'Canal 6', 'unit_06': 'in', 'channel_07': 157.77, 'name_7': 'Canal 7', 'unit_07': 'kg', 'channel_08': 172.0, 'name_8': 'Canal 8', 'unit_08': 'm', 'channel_09': 176.8, 'name_9': 'Canal 9', 'unit_09': 'bar', 'channel_10': 188.13, 'name_10': 'Canal 10', 'unit_10': 'in', 'channel_11': 196.02, 'name_11': 'Canal 11', 'unit_11': 'l', 'channel_12': 210.05, 'name_12': 'Canal 12', 'unit_12': 'kg/m³', 'channel_13': 223.19, 'name_13': 'Canal 13', 'unit_13': 'm', 'channel_14': 233.74, 'name_14': 'Canal 14', 'unit_14': 'kPa', 'channel_15': 242.98, 'name_15': 'Canal 15', 'unit_15': 'kg/m³', 'channel_16': 252.94, 'name_16': 'Canal 16', 'unit_16': 'kg/m³', 'channel_17': 263.1, 'name_17': 'Canal 17', 'unit_17': 'kPa', 'channel_18': 271.41, 'name_18': 'Canal 18', 'unit_18': 'gal'}}
# [Kafka] Sent from fgenerador6_data: {'table': 'fgenerador6_data', 'data': {'id': 1440, 'timestamp': '2025-06-01T23:59:00', 'rig_config_id': 1, 'session_timestamp': '2025-06-05T00:00:00', 'channel_01': 98.99, 'name_1': 'Canal 1', 'unit_01': 'kg/m³', 'channel_02': 112.52, 'name_2': 'Canal 2', 'unit_02': 'ton', 'channel_03': 121.73, 'name_3': 'Canal 3', 'unit_03': 'ton', 'channel_04': 126.33, 'name_4': 'Canal 4', 'unit_04': 'scaled', 'channel_05': 140.52, 'name_5': 'Canal 5', 'unit_05': 'bar', 'channel_06': 152.4, 'name_6': 'Canal 6', 'unit_06': 'l/min', 'channel_07': 161.18, 'name_7': 'Canal 7', 'unit_07': 'rpm', 'channel_08': 166.14, 'name_8': 'Canal 8', 'unit_08': 'l', 'channel_09': 178.19, 'name_9': 'Canal 9', 'unit_09': 'm³/h', 'channel_10': 193.43, 'name_10': 'Canal 10', 'unit_10': 'scaled', 'channel_11': 198.09, 'name_11': 'Canal 11', 'unit_11': 'rpm', 'channel_12': 211.05, 'name_12': 'Canal 12', 'unit_12': 'gpm', 'channel_13': 222.22, 'name_13': 'Canal 13', 'unit_13': 'lb/ft³', 'channel_14': 234.79, 'name_14': 'Canal 14', 'unit_14': 'scaled', 'channel_15': 236.27, 'name_15': 'Canal 15', 'unit_15': 'l', 'channel_16': 248.95, 'name_16': 'Canal 16', 'unit_16': 'gal', 'channel_17': 259.03, 'name_17': 'Canal 17', 'unit_17': 'psi', 'channel_18': 265.39, 'name_18': 'Canal 18', 'unit_18': 'in'}}
# [Kafka] Sent from fgenerador7_data: {'table': 'fgenerador7_data', 'data': {'id': 1440, 'timestamp': '2025-06-01T23:59:00', 'rig_config_id': 1, 'session_timestamp': '2025-06-05T00:00:00', 'channel_01': 97.09, 'name_1': 'Canal 1', 'unit_01': 'rpm', 'channel_02': 106.88, 'name_2': 'Canal 2', 'unit_02': 'kPa', 'channel_03': 117.2, 'name_3': 'Canal 3', 'unit_03': 'kPa', 'channel_04': 128.74, 'name_4': 'Canal 4', 'unit_04': 'kg/m³', 'channel_05': 144.44, 'name_5': 'Canal 5', 'unit_05': 'kg/m³', 'channel_06': 152.27, 'name_6': 'Canal 6', 'unit_06': 'l', 'channel_07': 158.88, 'name_7': 'Canal 7', 'unit_07': 'scaled', 'channel_08': 168.62, 'name_8': 'Canal 8', 'unit_08': 'rpm', 'channel_09': 181.76, 'name_9': 'Canal 9', 'unit_09': 'scaled', 'channel_10': 190.39, 'name_10': 'Canal 10', 'unit_10': 'kg', 'channel_11': 195.58, 'name_11': 'Canal 11', 'unit_11': 'm³/h', 'channel_12': 205.43, 'name_12': 'Canal 12', 'unit_12': 'scaled', 'channel_13': 217.62, 'name_13': 'Canal 13', 'unit_13': 'm³', 'channel_14': 234.56, 'name_14': 'Canal 14', 'unit_14': 'ton', 'channel_15': 236.14, 'name_15': 'Canal 15', 'unit_15': 'kg/m³', 'channel_16': 247.18, 'name_16': 'Canal 16', 'unit_16': 'kg/m³', 'channel_17': 255.55, 'name_17': 'Canal 17', 'unit_17': 'psi', 'channel_18': 274.47, 'name_18': 'Canal 18', 'unit_18': 'scaled'}}
# [Kafka] Sent from rig_config: {'table': 'rig_config', 'data': {'id': 3, 'timestamp': '2025-06-08T08:32:58', 'nombre': 'rig odin', 'contratista': 'opex', 'objetivo_profundidad': 10.0, 'region': 'sur', 'ubicacion': 'cuazacualco', 'latitud': '100', 'longitud': '34', 'distancia_costa': 10.0, 'puerto_cercano': 'veracruz', 'tipo': 'Terrestre', 'operador': 'bord', 'profundidad_agua': 10.0, 'capacidad_carga': 10.0, 'potencia': 3500, 'presion_maxima': 500.0, 'notas': 'prueba 2', 'config_json': '{"general": {"nombre": "rig odin", "contratista": "opex", "objetivo_profundidad": 10.0, "region": "sur", "ubicacion": "cuazacualco", "latitud": "100", "longitud": "34", "distancia_costa": 10.0, "puerto_cercano": "veracruz", "tipo": "Terrestre", "operador": "bord"}, "capacidades": {"profundidad_agua": 10.0, "capacidad_carga": 10.0, "potencia": 3500, "presion_maxima": 500.0}, "notas": "prueba 2"}'}}
# [Kafka] Sent from wits_data: {'table': 'wits_data', 'data': {'id': 1467, 'timestamp': '2025-06-20T14:37:50', 'rig_config_id': 3, 'session_timestamp': '2025-06-08T13:00:00', 'N0105': 'Fecha', 'W0105': 20250600.0, 'U0105': 'unidad', 'N0106': 'Hora', 'W0106': 143750.0, 'U0106': 'unidad', 'N0107': 'Flow Rate', 'W0107': None, 'U0107': 'gpm', 'N0108': 'Profundidad de la barrena', 'W0108': 998.0, 'U0108': 'm', 'N0110': 'Profundidad perforada', 'W0110': 1001.0, 'U0110': 'm', 'N0111': 'Profundidad vertical', 'W0111': None, 'U0111': 'm', 'N0112': 'posicion del block', 'W0112': 30.0, 'U0112': 'm', 'N0113': 'Ritmo de penetración (ROP)', 'W0113': 0.0, 'U0113': 'm', 'N0114': 'Carga en gancho', 'W0114': 6000.0, 'U0114': 'kg', 'N0116': 'Peso sobre la barrena', 'W0116': 0.0, 'U0116': 'kg', 'N0118': 'Torque', 'W0118': 0.0, 'U0118': 'rpm', 'N0120': 'RPM', 'W0120': 0.0, 'U0120': 'rpm', 'N0121': 'Presión de Bombeo 1', 'W0121': 0.0, 'U0121': 'psi', 'N0122': 'Presión de Bombeo 2', 'W0122': None, 'U0122': 'psi', 'N0123': 'SPM1', 'W0123': None, 'U0123': 'rpm', 'N0124': 'SPM2', 'W0124': None, 'U0124': 'rpm', 'N0125': 'SPM3', 'W0125': None, 'U0125': 'rpm', 'N0127': 'Volumen ganado', 'W0127': None, 'U0127': 'l', 'N0128': 'Flujo de salida', 'W0128': None, 'U0128': 'gpm', 'N0129': 'Pump Efficiency', 'W0129': None, 'U0129': '%', 'N0130': 'Gasto de entrada', 'W0130': 0.0, 'U0130': 'gpm', 'N0131': 'Densidad salida', 'W0131': None, 'U0131': 'kg/m³', 'N0132': 'Densidad entrada', 'W0132': None, 'U0132': 'kg/m³', 'N0133': 'Temperatura salida', 'W0133': None, 'U0133': '°C', 'N0134': 'Temperatura entrada', 'W0134': None, 'U0134': '°C', 'Cuñas': 'FUERA', 'Actividad': 'ESTACIONADO', 'Subactividad': 'ESPERANDO OPERACION', 'config_json': '{"wits_values": {"0010": "1", "10": "1", "010": "1", "0106": "0143750", "106": "0143750", "0105": "020250620", "105": "020250620", "0108": "0998", "108": "0998", "0110": "01001", "110": "01001", "0112": "030", "112": "030", "0113": "00", "113": "00", "0114": "06000", "114": "06000", "0116": "00", "116": "00", "0118": "00", "118": "00", "0120": "00", "120": "00", "0121": "00", "121": "00", "0130": "00", "130": "00", "1435": "59", "1436": "59", "1437": "49"}, "states": {"cunas": "FUERA", "actividad": "ESTACIONADO", "subactividad": "ESPERANDO OPERACION"}}'}}
# ==============================
#
#
# Lectura interrumpida por el usuario.
# Consumer cerrado correctamente.

# %%
from kafka import KafkaConsumer
import json
import time

# Configuración del consumidor
consumer = KafkaConsumer(
    'rigcore-data',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='latest',
    enable_auto_commit=True,
    group_id='rigcore-consumer-group',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

print("Escuchando mensajes en el topic 'rigcore-data'...")

try:
    for message in consumer:
        data = message.value
        table = data.get('table')
        row_data = data.get('data')

        if table and row_data:
            print(f"\n=== Mensaje de la tabla: {table} ===")
            for key, value in row_data.items():
                print(f"{key}: {value}")
        else:
            print(f"[WARN] Formato inesperado en el mensaje: {data}")

        time.sleep(1)

except KeyboardInterrupt:
    print("\nLectura interrumpida por el usuario.")

finally:
    consumer.close()
    print("Consumer cerrado correctamente.")
# Out:
# Escuchando mensajes en el topic 'rigcore-data'...
#
# === Mensaje de la tabla: fgenerador5_data ===
# id: 1440
# timestamp: 2025-06-01T23:59:00
# rig_config_id: 1
# session_timestamp: 2025-06-05T00:00:00
# channel_01: 98.78
# name_1: Canal 1
# unit_01: kg/m³
# channel_02: 111.17
# name_2: Canal 2
# unit_02: deg/s
# channel_03: 122.77
# name_3: Canal 3
# unit_03: l
# channel_04: 127.67
# name_4: Canal 4
# unit_04: lb
# channel_05: 143.26
# name_5: Canal 5
# unit_05: ft
# channel_06: 151.09
# name_6: Canal 6
# unit_06: in
# channel_07: 157.77
# name_7: Canal 7
# unit_07: kg
# channel_08: 172.0
# name_8: Canal 8
# unit_08: m
# channel_09: 176.8
# name_9: Canal 9
# unit_09: bar
# channel_10: 188.13
# name_10: Canal 10
# unit_10: in
# channel_11: 196.02
# name_11: Canal 11
# unit_11: l
# channel_12: 210.05
# name_12: Canal 12
# unit_12: kg/m³
# channel_13: 223.19
# name_13: Canal 13
# unit_13: m
# channel_14: 233.74
# name_14: Canal 14
# unit_14: kPa
# channel_15: 242.98
# name_15: Canal 15
# unit_15: kg/m³
# channel_16: 252.94
# name_16: Canal 16
# unit_16: kg/m³
# channel_17: 263.1
# name_17: Canal 17
# unit_17: kPa
# channel_18: 271.41
# name_18: Canal 18
# unit_18: gal
#
# === Mensaje de la tabla: fgenerador6_data ===
# id: 1440
# timestamp: 2025-06-01T23:59:00
# rig_config_id: 1
# session_timestamp: 2025-06-05T00:00:00
# channel_01: 98.99
# name_1: Canal 1
# unit_01: kg/m³
# channel_02: 112.52
# name_2: Canal 2
# unit_02: ton
# channel_03: 121.73
# name_3: Canal 3
# unit_03: ton
# channel_04: 126.33
# name_4: Canal 4
# unit_04: scaled
# channel_05: 140.52
# name_5: Canal 5
# unit_05: bar
# channel_06: 152.4
# name_6: Canal 6
# unit_06: l/min
# channel_07: 161.18
# name_7: Canal 7
# unit_07: rpm
# channel_08: 166.14
# name_8: Canal 8
# unit_08: l
# channel_09: 178.19
# name_9: Canal 9
# unit_09: m³/h
# channel_10: 193.43
# name_10: Canal 10
# unit_10: scaled
# channel_11: 198.09
# name_11: Canal 11
# unit_11: rpm
# channel_12: 211.05
# name_12: Canal 12
# unit_12: gpm
# channel_13: 222.22
# name_13: Canal 13
# unit_13: lb/ft³
# channel_14: 234.79
# name_14: Canal 14
# unit_14: scaled
# channel_15: 236.27
# name_15: Canal 15
# unit_15: l
# channel_16: 248.95
# name_16: Canal 16
# unit_16: gal
# channel_17: 259.03
# name_17: Canal 17
# unit_17: psi
# channel_18: 265.39
# name_18: Canal 18
# unit_18: in
#
# === Mensaje de la tabla: fgenerador7_data ===
# id: 1440
# timestamp: 2025-06-01T23:59:00
# rig_config_id: 1
# session_timestamp: 2025-06-05T00:00:00
# channel_01: 97.09
# name_1: Canal 1
# unit_01: rpm
# channel_02: 106.88
# name_2: Canal 2
# unit_02: kPa
# channel_03: 117.2
# name_3: Canal 3
# unit_03: kPa
# channel_04: 128.74
# name_4: Canal 4
# unit_04: kg/m³
# channel_05: 144.44
# name_5: Canal 5
# unit_05: kg/m³
# channel_06: 152.27
# name_6: Canal 6
# unit_06: l
# channel_07: 158.88
# name_7: Canal 7
# unit_07: scaled
# channel_08: 168.62
# name_8: Canal 8
# unit_08: rpm
# channel_09: 181.76
# name_9: Canal 9
# unit_09: scaled
# channel_10: 190.39
# name_10: Canal 10
# unit_10: kg
# channel_11: 195.58
# name_11: Canal 11
# unit_11: m³/h
# channel_12: 205.43
# name_12: Canal 12
# unit_12: scaled
# channel_13: 217.62
# name_13: Canal 13
# unit_13: m³
# channel_14: 234.56
# name_14: Canal 14
# unit_14: ton
# channel_15: 236.14
# name_15: Canal 15
# unit_15: kg/m³
# channel_16: 247.18
# name_16: Canal 16
# unit_16: kg/m³
# channel_17: 255.55
# name_17: Canal 17
# unit_17: psi
# channel_18: 274.47
# name_18: Canal 18
# unit_18: scaled
#
# Lectura interrumpida por el usuario.
# Consumer cerrado correctamente.

# %%
from kafka import KafkaConsumer
import json
import time

# Configurar el consumidor
consumer = KafkaConsumer(
    'rigcore-data',
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='latest',
    enable_auto_commit=True,
    group_id='rigcore-consumer-group',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)


def main():
    print("Iniciando consumer en formato JSON...")
    try:
        while True:
            start_time = time.time()
            data_batch = {}

            # Recolectar mensajes durante 3 segundos
            while time.time() - start_time < 3:
                raw_msgs = consumer.poll(timeout_ms=100)
                for tp, messages in raw_msgs.items():
                    for message in messages:
                        value = message.value
                        table = value.get("table")
                        data = value.get("data")
                        if table and data:
                            # Reemplaza con la última versión
                            data_batch[table] = data

            # Imprimir el batch completo como JSON
            if data_batch:
                json_output = []
                for table, data in data_batch.items():
                    json_output.append({
                        "table": table,
                        "data": data
                    })

                print(json.dumps(json_output, indent=2, ensure_ascii=False))
            else:
                print("[]")

    except KeyboardInterrupt:
        print("Consumer detenido manualmente.")
    finally:
        consumer.close()


if __name__ == "__main__":
    main()
# Out:
# Iniciando consumer en formato JSON...
# []
# []
# []
# []
# []
# []
# []
# []
# Consumer detenido manualmente.
